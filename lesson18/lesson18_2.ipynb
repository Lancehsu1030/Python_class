# %%
import os  

#取得目前路徑
current_directory = os.getcwd() 

# 取得該目錄下的`data`資料夾內的`每日各站進出站人數2020.csv`檔案路徑
file_path = os.path.join(current_directory, "data", "每日各站進出站人數2020.csv")

print(file_path)
# Out:
# c:\Users\顏于雅\Documents\github\Python_class\lesson18\data\每日各站進出站人數2020.csv
