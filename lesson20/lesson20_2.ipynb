# %%
from tools import all_data_concat
import pandas as pd 

all_data = all_data_concat()
# 欄位`乘車日期`是數字格式,要轉成日期格式
all_data['乘車日期'] = pd.to_datetime(all_data['乘車日期'], format='%Y%m%d')

# 取出日期的年份,建立一個新的欄位`年份`
all_data['年份'] = all_data['乘車日期'].dt.year

# 取出期期的月份,建立一個新的欄位`月份`
all_data['月份'] = all_data['乘車日期'].dt.month

all_data.head()
# Out:
#         乘車日期  車站代碼  進站人數  出站人數 車站名稱                   車站地址    年份  月份
# 0 2019-04-23   900  8442  7743   基隆            基隆市仁愛區港西街5號  2019   4
# 1 2019-04-23   910  1394  1348   三坑     基隆市仁愛區德厚里龍安街 206 號  2019   4
# 2 2019-04-23   920  2770  2423   八堵     基隆市暖暖區八南里八堵路 142 號  2019   4
# 3 2019-04-23   930  6113  6335   七堵       基隆市七堵區長興里東新街 2 號  2019   4
# 4 2019-04-23   940  2680  2726   百福  基隆市七堵區堵南里明德三路 1 之 1 號  2019   4

# %%
df1 = all_data.groupby(['車站名稱','年份','月份'])[['進站人數','出站人數']].agg([('平均', 'mean'), ('總和', 'sum')])
df1
# Out:
#                      進站人數                 出站人數
#                        平均      總和           平均      總和
# 車站名稱 年份   月份
# 七堵   2019 4   5838.875000   46711  5977.125000   47817
#           5   6012.903226  186400  6160.806452  190985
#           6   5795.100000  173853  5908.066667  177242
#           7   5889.322581  182569  6135.419355  190198
#           8   5569.258065  172647  5763.806452  178678
# ...                   ...     ...          ...     ...
# 龜山   2023 8     74.774194    2318    76.709677    2378
#           9     79.933333    2398    79.766667    2393
#           10    85.806452    2660    86.096774    2669
#           11    85.433333    2563    86.466667    2594
#           12    99.709677    3091    90.129032    2794
#
# [13619 rows x 4 columns]

# %%
# df1.loc[('七堵')]
# df1.loc[('七堵', 2020)]
df1.loc[('七堵', [2020, 2021])]
# df1.loc[('七堵')].loc[2020:2021]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 # df1.loc[('七堵')]
#       2 # df1.loc[('七堵', 2020)]
# ----> 3 df1.loc[('七堵', [2020, 2021])]
#       4 # df1.loc[('七堵')].loc[2020:2021]
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1369, in _LocIndexer._getitem_tuple(self, tup)
#    1367 with suppress(IndexingError):
#    1368     tup = self._expand_ellipsis(tup)
# -> 1369     return self._getitem_lowerdim(tup)
#    1371 # no multi-index, so validate all of the indexers
#    1372 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1042, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1040 # we may have a nested tuples indexer here
#    1041 if self._is_nested_tuple_indexer(tup):
# -> 1042     return self._getitem_nested_tuple(tup)
#    1044 # we maybe be using a tuple to represent multiple dimensions here
#    1045 ax0 = self.obj._get_axis(0)
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1154, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1151     axis -= 1
#    1152     continue
# -> 1154 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1155 axis -= 1
#    1157 # if we have a scalar, we are done
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexes\multi.py:2782, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2779 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2780     indexer = self._get_indexer_level_0(keyarr)
# -> 2782     self._raise_if_missing(key, indexer, axis_name)
#    2783     return self[indexer], indexer
#    2785 return super()._get_indexer_strict(key, axis_name)
#
# File c:\Users\顏于雅\Documents\github\Python_class\.venv\Lib\site-packages\pandas\core\indexes\multi.py:2800, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2798 cmask = check == -1
#    2799 if cmask.any():
# -> 2800     raise KeyError(f"{keyarr[cmask]} not in index")
#    2801 # We get here when levels still contain values which are not
#    2802 # actually in Index anymore
#    2803 raise KeyError(f"{keyarr} not in index")
#
# KeyError: '[2020 2021] not in index'
