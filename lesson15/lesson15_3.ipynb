# %%
import numpy as np
students = np.random.randint(50, high=101, size=(50, 5))
students.shape
# Out:
# (50, 5)

# %%
# ndarray的實體方法
students.sum(axis=1)
students.mean(axis=1)
# Out:
# array([73.4, 62. , 78. , 76.6, 72.6, 83. , 67.4, 80. , 68. , 64.6, 84.6,
#        78. , 64.8, 71.2, 79.6, 74.6, 76.2, 77.6, 81.4, 78.4, 74.6, 83. ,
#        72.2, 73.8, 62.8, 79.2, 70.8, 63.8, 74.4, 69. , 67.6, 70.8, 82.4,
#        70.4, 78.2, 76.2, 66.2, 79. , 78.2, 66.8, 69.8, 74.2, 61. , 81.8,
#        73.4, 73. , 73.8, 76.6, 71.6, 61.4])

# %%
# numpy內建的函式

np.sum(students, axis=1)
np.mean(students, axis=1)
# Out:
# array([73.4, 62. , 78. , 76.6, 72.6, 83. , 67.4, 80. , 68. , 64.6, 84.6,
#        78. , 64.8, 71.2, 79.6, 74.6, 76.2, 77.6, 81.4, 78.4, 74.6, 83. ,
#        72.2, 73.8, 62.8, 79.2, 70.8, 63.8, 74.4, 69. , 67.6, 70.8, 82.4,
#        70.4, 78.2, 76.2, 66.2, 79. , 78.2, 66.8, 69.8, 74.2, 61. , 81.8,
#        73.4, 73. , 73.8, 76.6, 71.6, 61.4])

# %%
# 1家分站30天的營收

oneStore = np.random.randint(100, 10000, size=(30,))
oneStore
# Out:
# array([3249, 2177, 9862, 3172, 5029, 8596, 1676, 8309, 4150, 7161, 4660,
#        2694, 5454, 2185, 3392, 9080, 6888, 7842, 9643, 2613, 7179, 4313,
#        6973, 8689, 8201, 1666, 4403, 6684, 7463, 3718], dtype=int32)

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

oneStoreCum = oneStore.cumsum()
oneStoreCum

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), oneStoreCum, 'r-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()

# %%
# 5家店30天的營收

fiveStore = np.random.randint(100, 10000, size=(5, 30))
fiveStore
# Out:
# array([[8906, 9203, 2891, 6020, 2915, 5394, 2929, 4880, 8538, 3216, 4879,
#         3921, 4409, 2435, 2758, 3776, 7624, 7883, 8136, 5280, 2596, 8345,
#         5518, 9640, 6938, 6987, 4168, 4286, 7329, 2683],
#        [6573, 5988, 1844,  383, 9967, 2935, 7134, 6159, 3953, 5079, 9509,
#         6772, 4054, 1993, 7396, 8888, 5134, 2303, 9715, 9249, 5786, 7408,
#         9093, 9304, 4492, 5090, 2216, 9506, 8227, 4522],
#        [2690, 7175, 7375, 6075, 5447, 6429,  149, 6656, 8746, 1364, 5620,
#         6830, 9064, 9446, 1756, 1767, 6151, 8955, 8519, 7429, 6778, 3956,
#          177, 5702, 5030, 5263, 9961,  442, 3850, 2165],
#        [ 839, 4989, 1110, 1642, 2660,  465, 9683, 3056, 1797, 8092, 2015,
#         6265, 6989, 9622, 7572, 9798, 7621, 4233, 7555, 8355, 4997, 2721,
#          641,  200, 4952, 3400, 5992, 3036, 5693, 2538],
#        [3027, 9305,  525, 7722, 1920, 8634, 5601, 5577, 1429, 1883, 3655,
#          267, 3160, 1482, 5501, 7531, 4862, 2553, 9665, 3017, 7253, 7728,
#         2358,  324, 6081, 8727, 1524,  839, 3442, 8551]], dtype=int32)

# %%
# 累計每天5家店的營收
fiveStoreCum = fiveStore.cumsum(axis=1)
fiveStoreCum
# Out:
# array([[  8906,  18109,  21000,  27020,  29935,  35329,  38258,  43138,
#          51676,  54892,  59771,  63692,  68101,  70536,  73294,  77070,
#          84694,  92577, 100713, 105993, 108589, 116934, 122452, 132092,
#         139030, 146017, 150185, 154471, 161800, 164483],
#        [  6573,  12561,  14405,  14788,  24755,  27690,  34824,  40983,
#          44936,  50015,  59524,  66296,  70350,  72343,  79739,  88627,
#          93761,  96064, 105779, 115028, 120814, 128222, 137315, 146619,
#         151111, 156201, 158417, 167923, 176150, 180672],
#        [  2690,   9865,  17240,  23315,  28762,  35191,  35340,  41996,
#          50742,  52106,  57726,  64556,  73620,  83066,  84822,  86589,
#          92740, 101695, 110214, 117643, 124421, 128377, 128554, 134256,
#         139286, 144549, 154510, 154952, 158802, 160967],
#        [   839,   5828,   6938,   8580,  11240,  11705,  21388,  24444,
#          26241,  34333,  36348,  42613,  49602,  59224,  66796,  76594,
#          84215,  88448,  96003, 104358, 109355, 112076, 112717, 112917,
#         117869, 121269, 127261, 130297, 135990, 138528],
#        [  3027,  12332,  12857,  20579,  22499,  31133,  36734,  42311,
#          43740,  45623,  49278,  49545,  52705,  54187,  59688,  67219,
#          72081,  74634,  84299,  87316,  94569, 102297, 104655, 104979,
#         111060, 119787, 121311, 122150, 125592, 134143]])

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), fiveStoreCum[0], 'r-')
axes.plot(range(1, 31), fiveStoreCum[1], 'y-')
axes.plot(range(1, 31), fiveStoreCum[2], 'g-')
axes.plot(range(1, 31), fiveStoreCum[3], 'm-')
axes.plot(range(1, 31), fiveStoreCum[4], 'c-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()
